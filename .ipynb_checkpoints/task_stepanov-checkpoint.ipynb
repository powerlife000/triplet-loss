# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import Dataset, TensorDataset, DataLoader
from torchvision import transforms
import copy
from sklearn.model_selection import train_test_split

# %%
margin = 1

# %% [markdown]
# # Загружаем данные

# %%
buy_patterns = np.load('data/buy_patterns.npy')

# %%
buy_patterns_clusters = np.load('data/buy_patterns_clusters.npy')

# %%
sell_patterns = np.load('data/sell_patterns.npy')

# %%
sell_patterns_clusters = np.load('data/sell_patterns_clusters.npy')

# %%
shift_sell_patterns_clusters = sell_patterns_clusters + 2

# %% [markdown]
# # Объединяем датасеты

# %%
add_num_data = 17

# %%
patterns = np.concatenate((buy_patterns, sell_patterns), axis=0)
patterns = np.float32(patterns)

# %%
patterns_clusters = np.concatenate((buy_patterns_clusters, shift_sell_patterns_clusters), axis=0)
patterns_clusters.shape
# Out:
# (55,)

# %%
def get_data(patterns_init, patterns_clusters_init, need_transform = True, need_reshape = True, split = 0.9, random_state = 42):
    
    patterns = copy.deepcopy(patterns_init)
    patterns_clusters = copy.deepcopy(patterns_clusters_init)
    
    if need_reshape:
        patterns = patterns.reshape(patterns.shape[0],1,patterns.shape[1],patterns.shape[2])
        
    X_train, X_test, y_train, y_test = train_test_split(patterns, patterns_clusters, test_size=(1-split), random_state=random_state)
    
    X_train = torch.tensor(X_train)
    X_test = torch.tensor(X_test)

    if need_transform:
        # #Изменяем размерность
        transform = transforms.Resize((28,28))
        X_train = transform(X_train)
        X_test = transform(X_test)
    
    y_train = torch.tensor(y_train)
    y_test = torch.tensor(y_test)
    
    
    train_dataset = TensorDataset(X_train,y_train) # create your datset
    test_dataset = TensorDataset(X_test,y_test) # create your datset
    
    train_dataset.train = True
    train_dataset.transform = transforms.Compose([
        # you can add other transformations in this list
        transforms.ToTensor()
    ])
    train_dataset.train_data = train_dataset.tensors[0]
    train_dataset.train_labels = train_dataset.tensors[1]
    train_dataset.targets = train_dataset.train_labels
    train_dataset.class_to_idx = {'0 - zero': 0,
     '1 - one': 1,
     '2 - two': 2,
     '3 - three': 3}
    train_dataset.classes = ['0 - zero', '1 - one','2 - two','3 - three']
    
    test_dataset.train = False
    test_dataset.transform = transforms.Compose([
        # you can add other transformations in this list
        transforms.ToTensor()
    ])
    test_dataset.test_data = test_dataset.tensors[0]
    test_dataset.test_labels = test_dataset.tensors[1]
    test_dataset.targets = test_dataset.test_labels
    test_dataset.class_to_idx = {'0 - zero': 0,
     '1 - one': 1,
     '2 - two': 2,
     '3 - three': 3}
    train_dataset.classes = ['0 - zero', '1 - one','2 - two','3 - three']
    
    return train_dataset, test_dataset

# %%
def get_data_v2(patterns_init, patterns_clusters_init, need_transform = True, need_reshape = True, split = 0.9):
    #Неверно разбивает лейблы датасета
    
    patterns = copy.deepcopy(patterns_init)
    patterns_clusters = copy.deepcopy(patterns_clusters_init)
    
    if need_reshape:
        patterns = patterns.reshape(patterns.shape[0],1,patterns.shape[1],patterns.shape[2])
    
    patterns = torch.tensor(patterns)

    if need_transform:
        # #Изменяем размерность
        transform = transforms.Resize((28,28))
        patterns = transform(patterns)
    
    print(patterns_clusters.shape)
    
    patterns_clusters = torch.tensor(patterns_clusters)
    
    
    dataset = TensorDataset(patterns,patterns_clusters) # create your datset
    
    train_size = int(split * len(dataset))
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
    
    train_dataset.train = True
    train_dataset.transform = transforms.Compose([
        # you can add other transformations in this list
        transforms.ToTensor()
    ])
    train_dataset.train_data = train_dataset.dataset.tensors[0]
    train_dataset.train_labels = train_dataset.dataset.tensors[1]
    train_dataset.targets = train_dataset.train_labels
    train_dataset.class_to_idx = {'0 - zero': 0,
     '1 - one': 1,
     '2 - two': 2,
     '3 - three': 3}
    train_dataset.classes = ['0 - zero', '1 - one','2 - two','3 - three']
    
    test_dataset.train = False
    test_dataset.transform = transforms.Compose([
        # you can add other transformations in this list
        transforms.ToTensor()
    ])
    test_dataset.test_data = test_dataset.dataset.tensors[0]
    test_dataset.test_labels = test_dataset.dataset.tensors[1]
    print(len(test_dataset.test_labels))
    test_dataset.targets = test_dataset.test_labels
    test_dataset.class_to_idx = {'0 - zero': 0,
     '1 - one': 1,
     '2 - two': 2,
     '3 - three': 3}
    train_dataset.classes = ['0 - zero', '1 - one','2 - two','3 - three']
    
    return train_dataset, test_dataset

# %%
train_dataset, test_dataset = get_data(patterns, patterns_clusters, need_transform = True, need_reshape = True, split = 0.9)
# Out:
# (55,)
# 6

# %%
n_classes = 4

# %%
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

from trainer import fit
import numpy as np
cuda = torch.cuda.is_available()

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

mnist_classes = ['0', '1', '2', '3']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

def plot_embeddings(embeddings, targets, xlim=None, ylim=None, pic_name = None):
    plt.figure(figsize=(10,10))
    for i in range(4):
        inds = np.where(targets==i)[0]
        plt.scatter(embeddings[inds,0], embeddings[inds,1], alpha=0.5, color=colors[i])
    if xlim:
        plt.xlim(xlim[0], xlim[1])
    if ylim:
        plt.ylim(ylim[0], ylim[1])
    plt.legend(mnist_classes)
    
    if pic_name:
        plt.savefig('pic_result/'+pic_name+'.png')

def extract_embeddings(dataloader, model):
    with torch.no_grad():
        model.eval()
        embeddings = np.zeros((len(dataloader.dataset), 2))
        labels = np.zeros(len(dataloader.dataset))
        k = 0
        for images, target in dataloader:
            if cuda:
                images = images.cuda()
            embeddings[k:k+len(images)] = model.get_embedding(images).data.cpu().numpy()
            labels[k:k+len(images)] = target.numpy()
            k += len(images)
    return embeddings, labels

# %% [markdown]
# # Baseline: Classification with softmax

# %%
# Set up data loaders
batch_size = 256
kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, **kwargs)

# Set up the network and training parameters
from networks import EmbeddingNet, ClassificationNet
from metrics import AccumulatedAccuracyMetric

embedding_net = EmbeddingNet()
model = ClassificationNet(embedding_net, n_classes=n_classes)
if cuda:
    model.cuda()
loss_fn = torch.nn.NLLLoss()
lr = 1e-2
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20
log_interval = 50

# %%
fit(train_loader, test_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, log_interval, metrics=[AccumulatedAccuracyMetric()])
# Out:
# C:\Program Files\Python310\lib\site-packages\torch\optim\lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Train: [0/49 (0%)]	Loss: 2.477918	Accuracy: 16.3265306122449
#
# Epoch: 1/20. Train set: Average loss: 2.4779	Accuracy: 16.3265306122449
# Epoch: 1/20. Validation set: Average loss: 170.7688	Accuracy: 16.666666666666668
# Train: [0/49 (0%)]	Loss: 91.883598	Accuracy: 32.6530612244898
#
# Epoch: 2/20. Train set: Average loss: 91.8836	Accuracy: 32.6530612244898
# Epoch: 2/20. Validation set: Average loss: 2769.3027	Accuracy: 33.333333333333336
# Train: [0/49 (0%)]	Loss: 4236.719727	Accuracy: 12.244897959183673
#
# Epoch: 3/20. Train set: Average loss: 4236.7197	Accuracy: 12.244897959183673
# Epoch: 3/20. Validation set: Average loss: 166.7577	Accuracy: 16.666666666666668
# Train: [0/49 (0%)]	Loss: 111.548347	Accuracy: 32.6530612244898
#
# Epoch: 4/20. Train set: Average loss: 111.5483	Accuracy: 32.6530612244898
# Epoch: 4/20. Validation set: Average loss: 346.8447	Accuracy: 33.333333333333336
# Train: [0/49 (0%)]	Loss: 489.595093	Accuracy: 12.244897959183673
#
# Epoch: 5/20. Train set: Average loss: 489.5951	Accuracy: 12.244897959183673
# Epoch: 5/20. Validation set: Average loss: 589.2816	Accuracy: 16.666666666666668
# Train: [0/49 (0%)]	Loss: 611.157471	Accuracy: 14.285714285714286
#
# Epoch: 6/20. Train set: Average loss: 611.1575	Accuracy: 14.285714285714286
# Epoch: 6/20. Validation set: Average loss: 39.4834	Accuracy: 16.666666666666668
# Train: [0/49 (0%)]	Loss: 31.377192	Accuracy: 14.285714285714286
#
# Epoch: 7/20. Train set: Average loss: 31.3772	Accuracy: 14.285714285714286
# Epoch: 7/20. Validation set: Average loss: 524.5637	Accuracy: 33.333333333333336
# Train: [0/49 (0%)]	Loss:
val_embeddings_baseline, val_labels_baseline = extract_embeddings(test_loader, model)
plot_embeddings(val_embeddings_baseline, val_labels_baseline, pic_name = 'baseline_val')

# %% [markdown]
# # НОВЫЕ ДАТАСЕТЫ ДЛЯ НЕЙРОННЫХ СЕТЕЙ НИЖЕ

# %%
train_dataset, test_dataset = get_data(patterns, patterns_clusters, need_transform = True, need_reshape = False, split = 0.9)
# Out:
# (55,)
# 6

# %% [markdown]
# # Siamese network

# %%
# Set up data loaders
from datasets import SiameseMNIST

siamese_train_dataset = SiameseMNIST(train_dataset) # Returns pairs of images and target same/different
siamese_test_dataset = SiameseMNIST(test_dataset)
batch_size = 128
kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
siamese_train_loader = torch.utils.data.DataLoader(siamese_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
siamese_test_loader = torch.utils.data.DataLoader(siamese_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)

# Set up the network and training parameters
from networks import EmbeddingNet, SiameseNet
from losses import ContrastiveLoss

margin = 1.
embedding_net = EmbeddingNet()
model = SiameseNet(embedding_net)
if cuda:
    model.cuda()
loss_fn = ContrastiveLoss(margin)
lr = 1e-3
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20
log_interval = 100

# %%
fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, log_interval)
# Out:
# Train: [0/49 (0%)]	Loss: 0.202558
#
# Epoch: 1/20. Train set: Average loss: 0.2026
# Epoch: 1/20. Validation set: Average loss: 0.2436
# Train: [0/49 (0%)]	Loss: 0.254123
#
# Epoch: 2/20. Train set: Average loss: 0.2541
# Epoch: 2/20. Validation set: Average loss: 0.2278
# Train: [0/49 (0%)]	Loss: 0.214415
#
# Epoch: 3/20. Train set: Average loss: 0.2144
# Epoch: 3/20. Validation set: Average loss: 0.2001
# Train: [0/49 (0%)]	Loss: 0.219538
#
# Epoch: 4/20. Train set: Average loss: 0.2195
# Epoch: 4/20. Validation set: Average loss: 0.1755
# Train: [0/49 (0%)]	Loss: 0.172801
#
# Epoch: 5/20. Train set: Average loss: 0.1728
# Epoch: 5/20. Validation set: Average loss: 0.2119
# Train: [0/49 (0%)]	Loss: 0.165225
#
# Epoch: 6/20. Train set: Average loss: 0.1652
# Epoch: 6/20. Validation set: Average loss: 0.2244
# Train: [0/49 (0%)]	Loss: 0.188662
#
# Epoch: 7/20. Train set: Average loss: 0.1887
# Epoch: 7/20. Validation set: Average loss: 0.1989
# Train: [0/49 (0%)]	Loss: 0.169408
#
# Epoch: 8/20. Train set: Average loss: 0.1694
# Epoch: 8/20. Validation set: Average loss: 0.1964
# Train: [0/49 (0%)]	Loss: 0.136176
#
# Epoch: 9/20. Train set: Average loss: 0.1362
# Epoch: 9/20. Validation set: Average loss: 0.1947
# Train: [0/49 (0%)]	Loss: 0.172420
#
# Epoch: 10/20. Train set: Average loss: 0.1724
# Epoch: 10/20. Validation set: Average loss: 0.1931
# Train: [0/49 (0%)]	Loss: 0.149228
#
# Epoch: 11/20. Train set: Average loss: 0.1492
# Epoch: 11/20. Validation set: Average loss: 0.1917
# Train: [0/49 (0%)]	Loss: 0.170493
#
# Epoch: 12/20. Train set: Average loss: 0.1705
# Epoch: 12/20. Validation set: Average loss: 0.1907
# Train: [0/49 (0%)]	Loss: 0.181853
#
# Epoch: 13/20. Train set: Average loss: 0.1819
# Epoch: 13/20. Validation set: Average loss: 0.1895
# Train: [0/49 (0%)]	Loss: 0.183455
#
# Epoch: 14/20. Train set: Average loss: 0.1835
# Epoch: 14/20. Validation set: Average loss: 0.1888
# Train: [0/49 (0%)]	Loss: 0.142513
#
# Epoch: 15/20. Train set: Average loss: 0.1425
# Epoch: 15/20. Validation set: Average loss: 0.1881
# Train: [0/49 (0%)]	Loss: 0.149020
#
# Epoch: 16/20. Train set: Average loss: 0.1490
# Epoch: 16/20. Validation set: Average loss: 0.1880
# Train: [0/49 (0%)]	Loss: 0.152722
#
# Epoch: 17/20. Train set: Average loss: 0.1527
# Epoch: 17/20. Validation set: Average loss: 0.1880
# Train: [0/49 (0%)]	Loss: 0.194077
#
# Epoch: 18/20. Train set: Average loss: 0.1941
# Epoch: 18/20. Validation set: Average loss: 0.1879
# Train: [0/49 (0%)]	Loss: 0.174846
#
# Epoch: 19/20. Train set: Average loss: 0.1748
# Epoch: 19/20. Validation set: Average loss: 0.1879
# Train: [0/49 (0%)]	Loss: 0.155917
#
# Epoch: 20/20. Train set: Average loss: 0.1559
# Epoch: 20/20. Validation set: Average loss: 0.1878

# %%
train_embeddings_cl, train_labels_cl = extract_embeddings(train_loader, model)
plot_embeddings(train_embeddings_cl, train_labels_cl, pic_name = 'siamese_train')
val_embeddings_cl, val_labels_cl = extract_embeddings(test_loader, model)
plot_embeddings(val_embeddings_cl, val_labels_cl, pic_name = 'siamese_val')

# %% [markdown]
# # Triplet network

# %%
# Set up data loaders
from datasets import TripletMNIST

triplet_train_dataset = TripletMNIST(train_dataset) # Returns triplets of images
triplet_test_dataset = TripletMNIST(test_dataset)
batch_size = 128
kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
triplet_train_loader = torch.utils.data.DataLoader(triplet_train_dataset, batch_size=batch_size, shuffle=True, **kwargs)
triplet_test_loader = torch.utils.data.DataLoader(triplet_test_dataset, batch_size=batch_size, shuffle=False, **kwargs)

# Set up the network and training parameters
from networks import EmbeddingNet, TripletNet
from losses import TripletLoss

margin = 1.
embedding_net = EmbeddingNet()
model = TripletNet(embedding_net)
if cuda:
    model.cuda()
loss_fn = TripletLoss(margin)
lr = 1e-3
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20
log_interval = 100

# %%
fit(triplet_train_loader, triplet_test_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, log_interval)
# Out:
# Train: [0/49 (0%)]	Loss: 1.000005
#
# Epoch: 1/20. Train set: Average loss: 1.0000
# Epoch: 1/20. Validation set: Average loss: 0.9999
# Train: [0/49 (0%)]	Loss: 1.000027
#
# Epoch: 2/20. Train set: Average loss: 1.0000
# Epoch: 2/20. Validation set: Average loss: 0.9989
# Train: [0/49 (0%)]	Loss: 0.999759
#
# Epoch: 3/20. Train set: Average loss: 0.9998
# Epoch: 3/20. Validation set: Average loss: 0.9961
# Train: [0/49 (0%)]	Loss: 0.998226
#
# Epoch: 4/20. Train set: Average loss: 0.9982
# Epoch: 4/20. Validation set: Average loss: 0.9888
# Train: [0/49 (0%)]	Loss: 0.995458
#
# Epoch: 5/20. Train set: Average loss: 0.9955
# Epoch: 5/20. Validation set: Average loss: 0.9685
# Train: [0/49 (0%)]	Loss: 0.979629
#
# Epoch: 6/20. Train set: Average loss: 0.9796
# Epoch: 6/20. Validation set: Average loss: 0.9074
# Train: [0/49 (0%)]	Loss: 0.955678
#
# Epoch: 7/20. Train set: Average loss: 0.9557
# Epoch: 7/20. Validation set: Average loss: 0.7824
# Train: [0/49 (0%)]	Loss: 0.979754
#
# Epoch: 8/20. Train set: Average loss: 0.9798
# Epoch: 8/20. Validation set: Average loss: 0.7795
# Train: [0/49 (0%)]	Loss: 0.883554
#
# Epoch: 9/20. Train set: Average loss: 0.8836
# Epoch: 9/20. Validation set: Average loss: 0.7708
# Train: [0/49 (0%)]	Loss: 0.980350
#
# Epoch: 10/20. Train set: Average loss: 0.9804
# Epoch: 10/20. Validation set: Average loss: 0.7664
# Train: [0/49 (0%)]	Loss: 0.823510
#
# Epoch: 11/20. Train set: Average loss: 0.8235
# Epoch: 11/20. Validation set: Average loss: 0.7527
# Train: [0/49 (0%)]	Loss: 0.926892
#
# Epoch: 12/20. Train set: Average loss: 0.9269
# Epoch: 12/20. Validation set: Average loss: 0.7375
# Train: [0/49 (0%)]	Loss: 0.950579
#
# Epoch: 13/20. Train set: Average loss: 0.9506
# Epoch: 13/20. Validation set: Average loss: 0.7213
# Train: [0/49 (0%)]	Loss: 0.843424
#
# Epoch: 14/20. Train set: Average loss: 0.8434
# Epoch: 14/20. Validation set: Average loss: 0.7039
# Train: [0/49 (0%)]	Loss: 0.848416
#
# Epoch: 15/20. Train set: Average loss: 0.8484
# Epoch: 15/20. Validation set: Average loss: 0.6816
# Train: [0/49 (0%)]	Loss: 0.906427
#
# Epoch: 16/20. Train set: Average loss: 0.9064
# Epoch: 16/20. Validation set: Average loss: 0.6801
# Train: [0/49 (0%)]	Loss: 1.015116
#
# Epoch: 17/20. Train set: Average loss: 1.0151
# Epoch: 17/20. Validation set: Average loss: 0.6797
# Train: [0/49 (0%)]	Loss: 0.852489
#
# Epoch: 18/20. Train set: Average loss: 0.8525
# Epoch: 18/20. Validation set: Average loss: 0.6792
# Train: [0/49 (0%)]	Loss: 0.930799
#
# Epoch: 19/20. Train set: Average loss: 0.9308
# Epoch: 19/20. Validation set: Average loss: 0.6785
# Train: [0/49 (0%)]	Loss: 0.847049
#
# Epoch: 20/20. Train set: Average loss: 0.8470
# Epoch: 20/20. Validation set: Average loss: 0.6774

# %%
train_embeddings_tl, train_labels_tl = extract_embeddings(train_loader, model)
plot_embeddings(train_embeddings_tl, train_labels_tl, pic_name = 'triplet_train')
val_embeddings_tl, val_labels_tl = extract_embeddings(test_loader, model)
plot_embeddings(val_embeddings_tl, val_labels_tl, pic_name = 'triplet_val')

# %% [markdown]
# # ДАТАСЕТЫ ДЛЯ НЕЙРОННЫХ СЕТЕЙ НИЖЕ

# %%
patterns_1 = np.concatenate((patterns, patterns), axis=0)

for i in range(100):
    patterns_1 = np.concatenate((patterns_1, patterns), axis=0)

# %%
patterns_clusters_1 = np.concatenate((patterns_clusters, patterns_clusters), axis=0)

for i in range(100):
    patterns_clusters_1 = np.concatenate((patterns_clusters_1, patterns_clusters), axis=0)

# %%
train_dataset, test_dataset = get_data(patterns_1, patterns_clusters_1, need_transform = True, need_reshape = True, split = 0.9, random_state = 50)

# %%
# dir(train_dataset.train_data)

# %%
# dir(train_dataset.__len__)

# %% [markdown]
# # Online pair selection

# %%
from datasets import BalancedBatchSampler

# We'll create mini batches by sampling labels that will be present in the mini batch and number of examples from each class
train_batch_sampler = BalancedBatchSampler(train_dataset.train_labels, n_classes=4, n_samples=2)
test_batch_sampler = BalancedBatchSampler(test_dataset.test_labels, n_classes=4, n_samples=2)

kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
online_train_loader = torch.utils.data.DataLoader(train_dataset, batch_sampler=train_batch_sampler, **kwargs)
online_test_loader = torch.utils.data.DataLoader(test_dataset, batch_sampler=test_batch_sampler, **kwargs)

# Set up the network and training parameters
from networks import EmbeddingNet
from losses import OnlineContrastiveLoss
from utils import AllPositivePairSelector, HardNegativePairSelector # Strategies for selecting pairs within a minibatch

margin = 1.
embedding_net = EmbeddingNet()
model = embedding_net
if cuda:
    model.cuda()
loss_fn = OnlineContrastiveLoss(margin, HardNegativePairSelector())
lr = 1e-3
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20
log_interval = 50

# %%
fit(online_train_loader, online_test_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, log_interval)
# Out:
# Train: [0/5049 (0%)]	Loss: 8.734959
# Train: [400/5049 (8%)]	Loss: 40.399076
# Train: [800/5049 (16%)]	Loss: 0.941920
# Train: [1200/5049 (24%)]	Loss: 0.713703
# Train: [1600/5049 (32%)]	Loss: 0.684370
# Train: [2000/5049 (40%)]	Loss: 0.498078
# Train: [2400/5049 (48%)]	Loss: 0.650386
# Train: [2800/5049 (55%)]	Loss: 0.530615
# Train: [3200/5049 (63%)]	Loss: 0.479534
# Train: [3600/5049 (71%)]	Loss: 0.502627
# Train: [4000/5049 (79%)]	Loss: 0.500100
# Train: [4400/5049 (87%)]	Loss: 0.469869
# Train: [4800/5049 (95%)]	Loss: 0.531483
#
# Epoch: 1/20. Train set: Average loss: 3.7535
# Epoch: 1/20. Validation set: Average loss: 0.4971
# Train: [0/5049 (0%)]	Loss: 0.465251
# Train: [400/5049 (8%)]	Loss: 0.479890
# Train: [800/5049 (16%)]	Loss: 0.463892
# Train: [1200/5049 (24%)]	Loss: 0.471463
# Train: [1600/5049 (32%)]	Loss: 0.445535
# Train: [2000/5049 (40%)]	Loss: 0.449736
# Train: [2400/5049 (48%)]	Loss: 0.420821
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 1.409667	Average nonzero triplets: 2.4901960784313726
# Train: [2000/5049 (40%)]	Loss: 1.210969	Average nonzero triplets: 2.237623762376238
# Train: [3000/5049 (60%)]	Loss: 0.376940	Average nonzero triplets: 1.9602649006622517
# Train: [4000/5049 (79%)]	Loss: 0.919918	Average nonzero triplets: 1.8855721393034826
# Train: [5000/5049 (99%)]	Loss: 1.182774	Average nonzero triplets: 1.8047808764940239
#
# Epoch: 5/20. Train set: Average loss: 1.0210	Average nonzero triplets: 1.8095238095238095
# Epoch: 5/20. Validation set: Average loss: 1.7813	Average nonzero triplets: 2.0714285714285716
# Train: [0/5049 (0%)]	Loss: 4.927059	Average nonzero triplets: 4.0
# Train: [1000/5049 (20%)]	Loss: 1.169593	Average nonzero triplets: 1.5686274509803921
# Train: [2000/5049 (40%)]	Loss: 2.740147	Average nonzero triplets: 4.9504950495049505
# Train: [3000/5049 (60%)]	Loss: 1.407626	Average nonzero triplets: 3.9205298013245033
# Train: [4000/5049 (79%)]	Loss: 1.556583	Average nonzero triplets: 3.3134328358208953
# Train: [5000/5049 (99%)]	Loss: 2.593630	Average nonzero triplets: 3.095617529880478
#
# Epoch: 6/20. Train set: Average loss: 1.8980	Average nonzero triplets: 3.0873015873015874
# Epoch: 6/20. Validation set: Average loss: 0.0630	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.165538	Average nonzero triplets: 1.196078431372549
# Train: [2000/5049 (40%)]	Loss: 1.026676	Average nonzero triplets: 1.1584158415841583
# Train: [3000/5049 (60%)]	Loss: 0.569919	Average nonzero triplets: 1.218543046357616
# Train: [4000/5049 (79%)]	Loss: 0.949433	Average nonzero triplets: 1.199004975124378
# Train: [5000/5049 (99%)]	Loss: 0.721248	Average nonzero triplets: 1.1752988047808766
#
# Epoch: 7/20. Train set: Average loss: 0.6811	Average nonzero triplets: 1.1746031746031746
# Epoch: 7/20. Validation set: Average loss: 2.9587	Average nonzero triplets: 1.0714285714285714
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.202769	Average nonzero triplets: 1.0392156862745099
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0198019801980198
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0132450331125828
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0099502487562189
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0079681274900398
#
# Epoch: 8/20. Train set: Average loss: 0.0402	Average nonzero triplets: 1.007936507936508
# Epoch: 8/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 9/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 9/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 10/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 10/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 11/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 11/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 12/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 12/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 13/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 13/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 14/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 14/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 15/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 15/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 16/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 16/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 17/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 17/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 18/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 18/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 19/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 19/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Train: [0/5049 (0%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [1000/5049 (20%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [2000/5049 (40%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [3000/5049 (60%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [4000/5049 (79%)]	Loss: 0.000000	Average nonzero triplets: 1.0
# Train: [5000/5049 (99%)]	Loss: 0.000000	Average nonzero triplets: 1.0
#
# Epoch: 20/20. Train set: Average loss: 0.0000	Average nonzero triplets: 1.0
# Epoch: 20/20. Validation set: Average loss: 0.0000	Average nonzero triplets: 1.0

# %%
train_embeddings_otl, train_labels_otl = extract_embeddings(train_loader, model)
plot_embeddings(train_embeddings_otl, train_labels_otl, pic_name = 'online_triplet_train')
val_embeddings_otl, val_labels_otl = extract_embeddings(test_loader, model)
plot_embeddings(val_embeddings_otl, val_labels_otl, pic_name = 'online_triplet_val')

# %%
x_lim = (np.min(train_embeddings_ocl[:,0]), np.max(train_embeddings_ocl[:,0]))
y_lim = (np.min(train_embeddings_ocl[:,1]), np.max(train_embeddings_ocl[:,1]))
plot_embeddings(train_embeddings_cl, train_labels_cl, x_lim, y_lim)
plot_embeddings(train_embeddings_ocl, train_labels_ocl, x_lim, y_lim)
